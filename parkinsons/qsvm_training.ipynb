# %%
from sklearn.feature_selection import VarianceThreshold
from sklearn.preprocessing import StandardScaler
import pandas as pd, numpy as np, matplotlib.pyplot as plt
from sklearn.decomposition import PCA

df = pd.read_csv('pd_speech_features.csv', header=1)


selector = VarianceThreshold(threshold=0.1)
selected_features = selector.fit_transform(df.drop(columns=['id', 'gender', 'class']))

scaler = StandardScaler()
scaled_features = scaler.fit_transform(selected_features)

pca_scaled = PCA(n_components=150, svd_solver='full')
pca_scaled.fit(scaled_features)

variance_scaled = pca_scaled.explained_variance_ratio_.cumsum()


transformed_scaled = pca_scaled.transform(scaled_features)

df_transformed_scaled = pd.DataFrame(data=transformed_scaled, columns=[f"PC{i+1}" for i in range(transformed_scaled.shape[1])])


X, y = pd.concat([df[["gender"]], df_transformed_scaled], axis=1), df["class"]
y_scaled = 2 * (y - 0.5)

# %%
import pennylane as qml

nqubits = 6
dev = qml.device("lightning.qubit", wires=nqubits)

@qml.qnode(dev)
def kernel_circ(a, b):
    qml.AmplitudeEmbedding(
        a, wires=range(nqubits), pad_with=0, normalize=True)
    qml.adjoint(qml.AmplitudeEmbedding(
        b, wires=range(nqubits), pad_with=0, normalize=True))
    return qml.probs(wires=range(nqubits))


from sklearn.svm import SVC
def qkernel(A, B):
    K = np.zeros((len(A), len(B)))
    for i, a in enumerate(A):
        print(f"Row {i+1}/{len(A)}...") #logging
        for j, b in enumerate(B):
            if j<i:
                K[i, j] = K[j, i]
                continue
            K[i, j] = kernel_circ(a, b)[0]
        print(f"  Finished row {i+1}")
    print("\t\tKERNEL\t\t\n\n")
    print(K)
    print("\n\n")
    #save kernel to file
    np.save("quantum_kernel.npy", K)
    return K

# %%
svm = SVC(kernel=qkernel, random_state=15)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_scaled, test_size=0.2, random_state=15)
X_train, y_train = X_train.to_numpy(), y_train.to_numpy()
X_test, y_test = X_test.to_numpy(), y_test.to_numpy()

# %%
svm.fit(X_train[:, :64], y_train)
# Out:
# Row 1/604...
#   Finished row 1
# Row 2/604...
#   Finished row 2
# Row 3/604...
#   Finished row 3
# Row 4/604...
#   Finished row 4
# Row 5/604...
#   Finished row 5
# Row 6/604...
#   Finished row 6
# Row 7/604...
#   Finished row 7
# Row 8/604...
#   Finished row 8
# Row 9/604...
#   Finished row 9
# Row 10/604...
#   Finished row 10
# Row 11/604...
#   Finished row 11
# Row 12/604...
#   Finished row 12
# Row 13/604...
#   Finished row 13
# Row 14/604...
#   Finished row 14
# Row 15/604...
#   Finished row 15
# Row 16/604...
#   Finished row 16
# Row 17/604...
#   Finished row 17
# Row 18/604...
#   Finished row 18
# Row 19/604...
#   Finished row 19
# Row 20/604...
#   Finished row 20
# Row 21/604...
#   Finished row 21
# Row 22/604...
#   Finished row 22
# Row 23/604...
#   Finished row 23
# Row 24/604...
#   Finished row 24
# Row 25/604...
#   Finished row 25
# Row 26/604...
#   Finished row 26
# Row 27/604...
#   Finished row 27
# Row 28/604...
#   Finished row 28
# Row 29/604...
#   Finished row 29
# Row 30/604...
#   Finished row 30
# Row 31/604...
#   Finished row 31
# Row 32/604...
#   Finished row 32
# Row 33/604...
#   Finished row 33
# Row 34/604...
#   Finished row 34
# Row 35/604...
#   Finished row 35
# Row 36/604...
#   Finished row 36
# Row 37/604...
#   Finished row 37
# Row 38/604...
#   Finished row 38
# Row 39/604...
#   Finished row 39
# Row 40/604...
#   Finished row 40
# Row 41/604...
#   Finished row 41
# Row 42/604...
#   Finished row 42
# Row 43/604...
#   Finished row 43
# Row 44/604...
#   Finished row 44
# Row 45/604...
#   Finished row 45
# Row 46/604...
#   Finished row 46
# Row 47/604...
#   Finished row 47
# Row 48/604...
#   Finished row 48
# Row 49/604...
#   Finished row 49
# Row 50/604...
#   Finished row 50
# Row 51/604...
#   Finished row 51
# Row 52/604...
#   Finished row 52
# Row 53/604...
#   Finished row 53
# Row 54/604...
#   Finished row 54
# Row 55/604...
#   Finished row 55
# Row 56/604...
#   Finished row 56
# Row 57/604...
#   Finished row 57
# Row 58/604...
#   Finished row 58
# Row 59/604...
#   Finished row 59
# Row 60/604...
#   Finished row 60
# Row 61/604...
#   Finished row 61
# Row 62/604...
#   Finished row 62
# Row 63/604...
#   Finished row 63
# Row 64/604...
#   Finished row 64
# Row 65/604...
#   Finished row 65
# Row 66/604...
#   Finished row 66
# Row 67/604...
#   Finished row 67
# Row 68/604...
#   Finished row 68
# Row 69/604...
#   Finished row 69
# Row 70/604...
#   Finished row 70
# Row 71/604...
#   Finished row 71
# Row 72/604...
#   Finished row 72
# Row 73/604...
#   Finished row 73
# Row 74/604...
#   Finished row 74
# Row 75/604...
#   Finished row 75
# Row 76/604...
#   Finished row 76
# Row 77/604...
#   Finished row 77
# Row 78/604...
#   Finished row 78
# Row 79/604...
#   Finished row 79
# Row 80/604...
#   Finished row 80
# Row 81/604...
#   Finished row 81
# Row 82/604...
#   Finished row 82
# Row 83/604...
#   Finished row 83
# Row 84/604...
#   Finished row 84
# Row 85/604...
#   Finished row 85
# Row 86/604...
#   Finished row 86
# Row 87/604...
#   Finished row 87
# Row 88/604...
#   Finished row 88
# Row 89/604...
#   Finished row 89
# Row 90/604...
#   Finished row 90
# Row 91/604...
#   Finished row 91
# Row 92/604...
#   Finished row 92
# Row 93/604...
#   Finished row 93
# Row 94/604...
#   Finished row 94
# Row 95/604...
#   Finished row 95
# Row 96/604...
#   Finished row 96
# Row 97/604...
#   Finished row 97
# Row 98/604...
#   Finished row 98
# Row 99/604...
#   Finished row 99
# Row 100/604...
#   Finished row 100
# Row 101/604...
#   Finished row 101
# Row 102/604...
#   Finished row 102
# Row 103/604...
#   Finished row 103
# Row 104/604...
#   Finished row 104
# Row 105/604...
#   Finished row 105
# Row 106/604...
#   Finished row 106
# Row 107/604...
#   Finished row 107
# Row 108/604...
#   Finished row 108
# Row 109/604...
#   Finished row 109
# Row 110/604...
#   Finished row 110
# Row 111/604...
#   Finished row 111
# Row 112/604...
#   Finished row 112
# Row 113/604...
#   Finished row 113
# Row 114/604...
#   Finished row 114
# Row 115/604...
#   Finished row 115
# Row 116/604...
#   Finished row 116
# Row 117/604...
#   Finished row 117
# Row 118/604...
#   Finished row 118
# Row 119/604...
#   Finished row 119
# Row 120/604...
#   Finished row 120
# Row 121/604...
#   Finished row 121
# Row 122/604...
#   Finished row 122
# Row 123/604...
#   Finished row 123
# Row 124/604...
#   Finished row 124
# Row 125/604...
#   Finished row 125
# Row 126/604...
#   Finished row 126
# Row 127/604...
#   Finished row 127
# Row 128/604...
#   Finished row 128
# Row 129/604...
#   Finished row 129
# Row 130/604...
#   Finished row 130
# Row 131/604...
#   Finished row 131
# Row 132/604...
#   Finished row 132
# Row 133/604...
#   Finished row 133
# Row 134/604...
#   Finished row 134
# Row 135/604...
#   Finished row 135
# Row 136/604...
#   Finished row 136
# Row 137/604...
#   Finished row 137
# Row 138/604...
#   Finished row 138
# Row 139/604...
#   Finished row 139
# Row 140/604...
#   Finished row 140
# Row 141/604...
#   Finished row 141
# Row 142/604...
#   Finished row 142
# Row 143/604...
#   Finished row 143
# Row 144/604...
#   Finished row 144
# Row 145/604...
#   Finished row 145
# Row 146/604...
#   Finished row 146
# Row 147/604...
#   Finished row 147
# Row 148/604...
#   Finished row 148
# Row 149/604...
#   Finished row 149
# Row 150/604...
#   Finished row 150
# Row 151/604...
#   Finished row 151
# Row 152/604...
#   Finished row 152
# Row 153/604...
#   Finished row 153
# Row 154/604...
#   Finished row 154
# Row 155/604...
#   Finished row 155
# Row 156/604...
#   Finished row 156
# Row 157/604...
#   Finished row 157
# Row 158/604...
#   Finished row 158
# Row 159/604...
#   Finished row 159
# Row 160/604...
#   Finished row 160
# Row 161/604...
#   Finished row 161
# Row 162/604...
#   Finished row 162
# Row 163/604...
#   Finished row 163
# Row 164/604...
#   Finished row 164
# Row 165/604...
#   Finished row 165
# Row 166/604...
#   Finished row 166
# Row 167/604...
#   Finished row 167
# Row 168/604...
#   Finished row 168
# Row 169/604...
#   Finished row 169
# Row 170/604...
#   Finished row 170
# Row 171/604...
#   Finished row 171
# Row 172/604...
#   Finished row 172
# Row 173/604...
#   Finished row 173
# Row 174/604...
#   Finished row 174
# Row 175/604...
#   Finished row 175
# Row 176/604...
#   Finished row 176
# Row 177/604...
#   Finished row 177
# Row 178/604...
#   Finished row 178
# Row 179/604...
#   Finished row 179
# Row 180/604...
#   Finished row 180
# Row 181/604...
#   Finished row 181
# Row 182/604...
#   Finished row 182
# Row 183/604...
#   Finished row 183
# Row 184/604...
#   Finished row 184
# Row 185/604...
#   Finished row 185
# Row 186/604...
#   Finished row 186
# Row 187/604...
#   Finished row 187
# Row 188/604...
#   Finished row 188
# Row 189/604...
#   Finished row 189
# Row 190/604...
#   Finished row 190
# Row 191/604...
#   Finished row 191
# Row 192/604...
#   Finished row 192
# Row 193/604...
#   Finished row 193
# Row 194/604...
#   Finished row 194
# Row 195/604...
#   Finished row 195
# Row 196/604...
#   Finished row 196
# Row 197/604...
#   Finished row 197
# Row 198/604...
#   Finished row 198
# Row 199/604...
#   Finished row 199
# Row 200/604...
#   Finished row 200
# Row 201/604...
#   Finished row 201
# Row 202/604...
#   Finished row 202
# Row 203/604...
#   Finished row 203
# Row 204/604...
#   Finished row 204
# Row 205/604...
#   Finished row 205
# Row 206/604...
#   Finished row 206
# Row 207/604...
#   Finished row 207
# Row 208/604...
#   Finished row 208
# Row 209/604...
#   Finished row 209
# Row 210/604...
#   Finished row 210
# Row 211/604...
#   Finished row 211
# Row 212/604...
#   Finished row 212
# Row 213/604...
#   Finished row 213
# Row 214/604...
#   Finished row 214
# Row 215/604...
#   Finished row 215
# Row 216/604...
#   Finished row 216
# Row 217/604...
#   Finished row 217
# Row 218/604...
#   Finished row 218
# Row 219/604...
#   Finished row 219
# Row 220/604...
#   Finished row 220
# Row 221/604...
#   Finished row 221
# Row 222/604...
#   Finished row 222
# Row 223/604...
#   Finished row 223
# Row 224/604...
#   Finished row 224
# Row 225/604...
#   Finished row 225
# Row 226/604...
#   Finished row 226
# Row 227/604...
#   Finished row 227
# Row 228/604...
#   Finished row 228
# Row 229/604...
#   Finished row 229
# Row 230/604...
#   Finished row 230
# Row 231/604...
#   Finished row 231
# Row 232/604...
#   Finished row 232
# Row 233/604...
#   Finished row 233
# Row 234/604...
#   Finished row 234
# Row 235/604...
#   Finished row 235
# Row 236/604...
#   Finished row 236
# Row 237/604...
#   Finished row 237
# Row 238/604...
#   Finished row 238
# Row 239/604...
#   Finished row 239
# Row 240/604...
#   Finished row 240
# Row 241/604...
#   Finished row 241
# Row 242/604...
#   Finished row 242
# Row 243/604...
#   Finished row 243
# Row 244/604...
#   Finished row 244
# Row 245/604...
#   Finished row 245
# Row 246/604...
#   Finished row 246
# Row 247/604...
#   Finished row 247
# Row 248/604...
#   Finished row 248
# Row 249/604...
#   Finished row 249
# Row 250/604...
#   Finished row 250
# Row 251/604...
#   Finished row 251
# Row 252/604...
#   Finished row 252
# Row 253/604...
#   Finished row 253
# Row 254/604...
#   Finished row 254
# Row 255/604...
#   Finished row 255
# Row 256/604...
#   Finished row 256
# Row 257/604...
#   Finished row 257
# Row 258/604...
#   Finished row 258
# Row 259/604...
#   Finished row 259
# Row 260/604...
#   Finished row 260
# Row 261/604...
#   Finished row 261
# Row 262/604...
#   Finished row 262
# Row 263/604...
#   Finished row 263
# Row 264/604...
#   Finished row 264
# Row 265/604...
#   Finished row 265
# Row 266/604...
#   Finished row 266
# Row 267/604...
#   Finished row 267
# Row 268/604...
#   Finished row 268
# Row 269/604...
#   Finished row 269
# Row 270/604...
#   Finished row 270
# Row 271/604...
#   Finished row 271
# Row 272/604...
#   Finished row 272
# Row 273/604...
#   Finished row 273
# Row 274/604...
#   Finished row 274
# Row 275/604...
#   Finished row 275
# Row 276/604...
#   Finished row 276
# Row 277/604...
#   Finished row 277
# Row 278/604...
#   Finished row 278
# Row 279/604...
#   Finished row 279
# Row 280/604...
#   Finished row 280
# Row 281/604...
#   Finished row 281
# Row 282/604...
#   Finished row 282
# Row 283/604...
#   Finished row 283
# Row 284/604...
#   Finished row 284
# Row 285/604...
#   Finished row 285
# Row 286/604...
#   Finished row 286
# Row 287/604...
#   Finished row 287
# Row 288/604...
#   Finished row 288
# Row 289/604...
#   Finished row 289
# Row 290/604...
#   Finished row 290
# Row 291/604...
#   Finished row 291
# Row 292/604...
#   Finished row 292
# Row 293/604...
#   Finished row 293
# Row 294/604...
#   Finished row 294
# Row 295/604...
#   Finished row 295
# Row 296/604...
#   Finished row 296
# Row 297/604...
#   Finished row 297
# Row 298/604...
#   Finished row 298
# Row 299/604...
#   Finished row 299
# Row 300/604...
#   Finished row 300
# Row 301/604...
#   Finished row 301
# Row 302/604...
#   Finished row 302
# Row 303/604...
#   Finished row 303
# Row 304/604...
#   Finished row 304
# Row 305/604...
#   Finished row 305
# Row 306/604...
#   Finished row 306
# Row 307/604...
#   Finished row 307
# Row 308/604...
#   Finished row 308
# Row 309/604...
#   Finished row 309
# Row 310/604...
#   Finished row 310
# Row 311/604...
#   Finished row 311
# Row 312/604...
#   Finished row 312
# Row 313/604...
#   Finished row 313
# Row 314/604...
#   Finished row 314
# Row 315/604...
#   Finished row 315
# Row 316/604...
#   Finished row 316
# Row 317/604...
#   Finished row 317
# Row 318/604...
#   Finished row 318
# Row 319/604...
#   Finished row 319
# Row 320/604...
#   Finished row 320
# Row 321/604...
#   Finished row 321
# Row 322/604...
#   Finished row 322
# Row 323/604...
#   Finished row 323
# Row 324/604...
#   Finished row 324
# Row 325/604...
#   Finished row 325
# Row 326/604...
#   Finished row 326
# Row 327/604...
#   Finished row 327
# Row 328/604...
#   Finished row 328
# Row 329/604...
#   Finished row 329
# Row 330/604...
#   Finished row 330
# Row 331/604...
#   Finished row 331
# Row 332/604...
#   Finished row 332
# Row 333/604...
#   Finished row 333
# Row 334/604...
#   Finished row 334
# Row 335/604...
#   Finished row 335
# Row 336/604...
#   Finished row 336
# Row 337/604...
#   Finished row 337
# Row 338/604...
#   Finished row 338
# Row 339/604...
#   Finished row 339
# Row 340/604...
#   Finished row 340
# Row 341/604...
#   Finished row 341
# Row 342/604...
#   Finished row 342
# Row 343/604...
#   Finished row 343
# Row 344/604...
#   Finished row 344
# Row 345/604...
#   Finished row 345
# Row 346/604...
#   Finished row 346
# Row 347/604...
#   Finished row 347
# Row 348/604...
#   Finished row 348
# Row 349/604...
#   Finished row 349
# Row 350/604...
#   Finished row 350
# Row 351/604...
#   Finished row 351
# Row 352/604...
#   Finished row 352
# Row 353/604...
#   Finished row 353
# Row 354/604...
#   Finished row 354
# Row 355/604...
#   Finished row 355
# Row 356/604...
#   Finished row 356
# Row 357/604...
#   Finished row 357
# Row 358/604...
#   Finished row 358
# Row 359/604...
#   Finished row 359
# Row 360/604...
#   Finished row 360
# Row 361/604...
#   Finished row 361
# Row 362/604...
#   Finished row 362
# Row 363/604...
#   Finished row 363
# Row 364/604...
#   Finished row 364
# Row 365/604...
#   Finished row 365
# Row 366/604...
#   Finished row 366
# Row 367/604...
#   Finished row 367
# Row 368/604...
#   Finished row 368
# Row 369/604...
#   Finished row 369
# Row 370/604...
#   Finished row 370
# Row 371/604...
#   Finished row 371
# Row 372/604...
#   Finished row 372
# Row 373/604...
#   Finished row 373
# Row 374/604...
#   Finished row 374
# Row 375/604...
#   Finished row 375
# Row 376/604...
#   Finished row 376
# Row 377/604...
#   Finished row 377
# Row 378/604...
#   Finished row 378
# Row 379/604...
#   Finished row 379
# Row 380/604...
#   Finished row 380
# Row 381/604...
#   Finished row 381
# Row 382/604...
#   Finished row 382
# Row 383/604...
#   Finished row 383
# Row 384/604...
#   Finished row 384
# Row 385/604...
#   Finished row 385
# Row 386/604...
#   Finished row 386
# Row 387/604...
#   Finished row 387
# Row 388/604...
#   Finished row 388
# Row 389/604...
#   Finished row 389
# Row 390/604...
#   Finished row 390
# Row 391/604...
#   Finished row 391
# Row 392/604...
#   Finished row 392
# Row 393/604...
#   Finished row 393
# Row 394/604...
#   Finished row 394
# Row 395/604...
#   Finished row 395
# Row 396/604...
#   Finished row 396
# Row 397/604...
#   Finished row 397
# Row 398/604...
#   Finished row 398
# Row 399/604...
#   Finished row 399
# Row 400/604...
#   Finished row 400
# Row 401/604...
#   Finished row 401
# Row 402/604...
#   Finished row 402
# Row 403/604...
#   Finished row 403
# Row 404/604...
#   Finished row 404
# Row 405/604...
#   Finished row 405
# Row 406/604...
#   Finished row 406
# Row 407/604...
#   Finished row 407
# Row 408/604...
#   Finished row 408
# Row 409/604...
#   Finished row 409
# Row 410/604...
#   Finished row 410
# Row 411/604...
#   Finished row 411
# Row 412/604...
#   Finished row 412
# Row 413/604...
#   Finished row 413
# Row 414/604...
#   Finished row 414
# Row 415/604...
#   Finished row 415
# Row 416/604...
#   Finished row 416
# Row 417/604...
#   Finished row 417
# Row 418/604...
#   Finished row 418
# Row 419/604...
#   Finished row 419
# Row 420/604...
#   Finished row 420
# Row 421/604...
#   Finished row 421
# Row 422/604...
#   Finished row 422
# Row 423/604...
#   Finished row 423
# Row 424/604...
#   Finished row 424
# Row 425/604...
#   Finished row 425
# Row 426/604...
#   Finished row 426
# Row 427/604...
#   Finished row 427
# Row 428/604...
#   Finished row 428
# Row 429/604...
#   Finished row 429
# Row 430/604...
#   Finished row 430
# Row 431/604...
#   Finished row 431
# Row 432/604...
#   Finished row 432
# Row 433/604...
#   Finished row 433
# Row 434/604...
#   Finished row 434
# Row 435/604...
#   Finished row 435
# Row 436/604...
#   Finished row 436
# Row 437/604...
#   Finished row 437
# Row 438/604...
#   Finished row 438
# Row 439/604...
#   Finished row 439
# Row 440/604...
#   Finished row 440
# Row 441/604...
#   Finished row 441
# Row 442/604...
#   Finished row 442
# Row 443/604...
#   Finished row 443
# Row 444/604...
#   Finished row 444
# Row 445/604...
#   Finished row 445
# Row 446/604...
#   Finished row 446
# Row 447/604...
#   Finished row 447
# Row 448/604...
#   Finished row 448
# Row 449/604...
#   Finished row 449
# Row 450/604...
#   Finished row 450
# Row 451/604...
#   Finished row 451
# Row 452/604...
#   Finished row 452
# Row 453/604...
#   Finished row 453
# Row 454/604...
#   Finished row 454
# Row 455/604...
#   Finished row 455
# Row 456/604...
#   Finished row 456
# Row 457/604...
#   Finished row 457
# Row 458/604...
#   Finished row 458
# Row 459/604...
#   Finished row 459
# Row 460/604...
#   Finished row 460
# Row 461/604...
#   Finished row 461
# Row 462/604...
#   Finished row 462
# Row 463/604...
#   Finished row 463
# Row 464/604...
#   Finished row 464
# Row 465/604...
#   Finished row 465
# Row 466/604...
#   Finished row 466
# Row 467/604...
#   Finished row 467
# Row 468/604...
#   Finished row 468
# Row 469/604...
#   Finished row 469
# Row 470/604...
#   Finished row 470
# Row 471/604...
#   Finished row 471
# Row 472/604...
#   Finished row 472
# Row 473/604...
#   Finished row 473
# Row 474/604...
#   Finished row 474
# Row 475/604...
#   Finished row 475
# Row 476/604...
#   Finished row 476
# Row 477/604...
#   Finished row 477
# Row 478/604...
#   Finished row 478
# Row 479/604...
#   Finished row 479
# Row 480/604...
#   Finished row 480
# Row 481/604...
#   Finished row 481
# Row 482/604...
#   Finished row 482
# Row 483/604...
#   Finished row 483
# Row 484/604...
#   Finished row 484
# Row 485/604...
#   Finished row 485
# Row 486/604...
#   Finished row 486
# Row 487/604...
#   Finished row 487
# Row 488/604...
#   Finished row 488
# Row 489/604...
#   Finished row 489
# Row 490/604...
#   Finished row 490
# Row 491/604...
#   Finished row 491
# Row 492/604...
#   Finished row 492
# Row 493/604...
#   Finished row 493
# Row 494/604...
#   Finished row 494
# Row 495/604...
#   Finished row 495
# Row 496/604...
#   Finished row 496
# Row 497/604...
#   Finished row 497
# Row 498/604...
#   Finished row 498
# Row 499/604...
#   Finished row 499
# Row 500/604...
#   Finished row 500
# Row 501/604...
#   Finished row 501
# Row 502/604...
#   Finished row 502
# Row 503/604...
#   Finished row 503
# Row 504/604...
#   Finished row 504
# Row 505/604...
#   Finished row 505
# Row 506/604...
#   Finished row 506
# Row 507/604...
#   Finished row 507
# Row 508/604...
#   Finished row 508
# Row 509/604...
#   Finished row 509
# Row 510/604...
#   Finished row 510
# Row 511/604...
#   Finished row 511
# Row 512/604...
#   Finished row 512
# Row 513/604...
#   Finished row 513
# Row 514/604...
#   Finished row 514
# Row 515/604...
#   Finished row 515
# Row 516/604...
#   Finished row 516
# Row 517/604...
#   Finished row 517
# Row 518/604...
#   Finished row 518
# Row 519/604...
#   Finished row 519
# Row 520/604...
#   Finished row 520
# Row 521/604...
#   Finished row 521
# Row 522/604...
#   Finished row 522
# Row 523/604...
#   Finished row 523
# Row 524/604...
#   Finished row 524
# Row 525/604...
#   Finished row 525
# Row 526/604...
#   Finished row 526
# Row 527/604...
#   Finished row 527
# Row 528/604...
#   Finished row 528
# Row 529/604...
#   Finished row 529
# Row 530/604...
#   Finished row 530
# Row 531/604...
#   Finished row 531
# Row 532/604...
#   Finished row 532
# Row 533/604...
#   Finished row 533
# Row 534/604...
#   Finished row 534
# Row 535/604...
#   Finished row 535
# Row 536/604...
#   Finished row 536
# Row 537/604...
#   Finished row 537
# Row 538/604...
#   Finished row 538
# Row 539/604...
#   Finished row 539
# Row 540/604...
#   Finished row 540
# Row 541/604...
#   Finished row 541
# Row 542/604...
#   Finished row 542
# Row 543/604...
#   Finished row 543
# Row 544/604...
#   Finished row 544
# Row 545/604...
#   Finished row 545
# Row 546/604...
#   Finished row 546
# Row 547/604...
#   Finished row 547
# Row 548/604...
#   Finished row 548
# Row 549/604...
#   Finished row 549
# Row 550/604...
#   Finished row 550
# Row 551/604...
#   Finished row 551
# Row 552/604...
#   Finished row 552
# Row 553/604...
#   Finished row 553
# Row 554/604...
#   Finished row 554
# Row 555/604...
#   Finished row 555
# Row 556/604...
#   Finished row 556
# Row 557/604...
#   Finished row 557
# Row 558/604...
#   Finished row 558
# Row 559/604...
#   Finished row 559
# Row 560/604...
#   Finished row 560
# Row 561/604...
#   Finished row 561
# Row 562/604...
#   Finished row 562
# Row 563/604...
#   Finished row 563
# Row 564/604...
#   Finished row 564
# Row 565/604...
#   Finished row 565
# Row 566/604...
#   Finished row 566
# Row 567/604...
#   Finished row 567
# Row 568/604...
#   Finished row 568
# Row 569/604...
#   Finished row 569
# Row 570/604...
#   Finished row 570
# Row 571/604...
#   Finished row 571
# Row 572/604...
#   Finished row 572
# Row 573/604...
#   Finished row 573
# Row 574/604...
#   Finished row 574
# Row 575/604...
#   Finished row 575
# Row 576/604...
#   Finished row 576
# Row 577/604...
#   Finished row 577
# Row 578/604...
#   Finished row 578
# Row 579/604...
#   Finished row 579
# Row 580/604...
#   Finished row 580
# Row 581/604...
#   Finished row 581
# Row 582/604...
#   Finished row 582
# Row 583/604...
#   Finished row 583
# Row 584/604...
#   Finished row 584
# Row 585/604...
#   Finished row 585
# Row 586/604...
#   Finished row 586
# Row 587/604...
#   Finished row 587
# Row 588/604...
#   Finished row 588
# Row 589/604...
#   Finished row 589
# Row 590/604...
#   Finished row 590
# Row 591/604...
#   Finished row 591
# Row 592/604...
#   Finished row 592
# Row 593/604...
#   Finished row 593
# Row 594/604...
#   Finished row 594
# Row 595/604...
#   Finished row 595
# Row 596/604...
#   Finished row 596
# Row 597/604...
#   Finished row 597
# Row 598/604...
#   Finished row 598
# Row 599/604...
#   Finished row 599
# Row 600/604...
#   Finished row 600
# Row 601/604...
#   Finished row 601
# Row 602/604...
#   Finished row 602
# Row 603/604...
#   Finished row 603
# Row 604/604...
#   Finished row 604
# 		KERNEL
#
#
# [[1.         0.03726543 0.35068867 ... 0.02961577 0.13684879 0.07325308]
#  [0.03726543 1.         0.03242403 ... 0.00844797 0.08249178 0.01830991]
#  [0.35068867 0.03242403 1.         ... 0.10942884 0.20859294 0.43731892]
#  ...
#  [0.02961577 0.00844797 0.10942884 ... 1.         0.00925936 0.0781455 ]
#  [0.13684879 0.08249178 0.20859294 ... 0.00925936 1.         0.09454531]
#  [0.07325308 0.01830991 0.43731892 ... 0.0781455  0.09454531 1.        ]]
# SVC(kernel=<function qkernel at 0x7c4851e83400>, random_state=15)

# %%
predictions = svm.predict(X_test[:, :64])
# Out:
# Row 1/152...
#   Finished row 1
# Row 2/152...
#   Finished row 2
# Row 3/152...
#   Finished row 3
# Row 4/152...
#   Finished row 4
# Row 5/152...
#   Finished row 5
# Row 6/152...
#   Finished row 6
# Row 7/152...
#   Finished row 7
# Row 8/152...
#   Finished row 8
# Row 9/152...
#   Finished row 9
# Row 10/152...
#   Finished row 10
# Row 11/152...
#   Finished row 11
# Row 12/152...
#   Finished row 12
# Row 13/152...
#   Finished row 13
# Row 14/152...
#   Finished row 14
# Row 15/152...
#   Finished row 15
# Row 16/152...
#   Finished row 16
# Row 17/152...
#   Finished row 17
# Row 18/152...
#   Finished row 18
# Row 19/152...
#   Finished row 19
# Row 20/152...
#   Finished row 20
# Row 21/152...
#   Finished row 21
# Row 22/152...
#   Finished row 22
# Row 23/152...
#   Finished row 23
# Row 24/152...
#   Finished row 24
# Row 25/152...
#   Finished row 25
# Row 26/152...
#   Finished row 26
# Row 27/152...
#   Finished row 27
# Row 28/152...
#   Finished row 28
# Row 29/152...
#   Finished row 29
# Row 30/152...
#   Finished row 30
# Row 31/152...
#   Finished row 31
# Row 32/152...
#   Finished row 32
# Row 33/152...
#   Finished row 33
# Row 34/152...
#   Finished row 34
# Row 35/152...
#   Finished row 35
# Row 36/152...
#   Finished row 36
# Row 37/152...
#   Finished row 37
# Row 38/152...
#   Finished row 38
# Row 39/152...
#   Finished row 39
# Row 40/152...
#   Finished row 40
# Row 41/152...
#   Finished row 41
# Row 42/152...
#   Finished row 42
# Row 43/152...
#   Finished row 43
# Row 44/152...
#   Finished row 44
# Row 45/152...
#   Finished row 45
# Row 46/152...
#   Finished row 46
# Row 47/152...
#   Finished row 47
# Row 48/152...
#   Finished row 48
# Row 49/152...
#   Finished row 49
# Row 50/152...
#   Finished row 50
# Row 51/152...
#   Finished row 51
# Row 52/152...
#   Finished row 52
# Row 53/152...
#   Finished row 53
# Row 54/152...
#   Finished row 54
# Row 55/152...
#   Finished row 55
# Row 56/152...
#   Finished row 56
# Row 57/152...
#   Finished row 57
# Row 58/152...
#   Finished row 58
# Row 59/152...
#   Finished row 59
# Row 60/152...
#   Finished row 60
# Row 61/152...
#   Finished row 61
# Row 62/152...
#   Finished row 62
# Row 63/152...
#   Finished row 63
# Row 64/152...
#   Finished row 64
# Row 65/152...
#   Finished row 65
# Row 66/152...
#   Finished row 66
# Row 67/152...
#   Finished row 67
# Row 68/152...
#   Finished row 68
# Row 69/152...
#   Finished row 69
# Row 70/152...
#   Finished row 70
# Row 71/152...
#   Finished row 71
# Row 72/152...
#   Finished row 72
# Row 73/152...
#   Finished row 73
# Row 74/152...
#   Finished row 74
# Row 75/152...
#   Finished row 75
# Row 76/152...
#   Finished row 76
# Row 77/152...
#   Finished row 77
# Row 78/152...
#   Finished row 78
# Row 79/152...
#   Finished row 79
# Row 80/152...
#   Finished row 80
# Row 81/152...
#   Finished row 81
# Row 82/152...
#   Finished row 82
# Row 83/152...
#   Finished row 83
# Row 84/152...
#   Finished row 84
# Row 85/152...
#   Finished row 85
# Row 86/152...
#   Finished row 86
# Row 87/152...
#   Finished row 87
# Row 88/152...
#   Finished row 88
# Row 89/152...
#   Finished row 89
# Row 90/152...
#   Finished row 90
# Row 91/152...
#   Finished row 91
# Row 92/152...
#   Finished row 92
# Row 93/152...
#   Finished row 93
# Row 94/152...
#   Finished row 94
# Row 95/152...
#   Finished row 95
# Row 96/152...
#   Finished row 96
# Row 97/152...
#   Finished row 97
# Row 98/152...
#   Finished row 98
# Row 99/152...
#   Finished row 99
# Row 100/152...
#   Finished row 100
# Row 101/152...
#   Finished row 101
# Row 102/152...
#   Finished row 102
# Row 103/152...
#   Finished row 103
# Row 104/152...
#   Finished row 104
# Row 105/152...
#   Finished row 105
# Row 106/152...
#   Finished row 106
# Row 107/152...
#   Finished row 107
# Row 108/152...
#   Finished row 108
# Row 109/152...
#   Finished row 109
# Row 110/152...
#   Finished row 110
# Row 111/152...
#   Finished row 111
# Row 112/152...
#   Finished row 112
# Row 113/152...
#   Finished row 113
# Row 114/152...
#   Finished row 114
# Row 115/152...
#   Finished row 115
# Row 116/152...
#   Finished row 116
# Row 117/152...
#   Finished row 117
# Row 118/152...
#   Finished row 118
# Row 119/152...
#   Finished row 119
# Row 120/152...
#   Finished row 120
# Row 121/152...
#   Finished row 121
# Row 122/152...
#   Finished row 122
# Row 123/152...
#   Finished row 123
# Row 124/152...
#   Finished row 124
# Row 125/152...
#   Finished row 125
# Row 126/152...
#   Finished row 126
# Row 127/152...
#   Finished row 127
# Row 128/152...
#   Finished row 128
# Row 129/152...
#   Finished row 129
# Row 130/152...
#   Finished row 130
# Row 131/152...
#   Finished row 131
# Row 132/152...
#   Finished row 132
# Row 133/152...
#   Finished row 133
# Row 134/152...
#   Finished row 134
# Row 135/152...
#   Finished row 135
# Row 136/152...
#   Finished row 136
# Row 137/152...
#   Finished row 137
# Row 138/152...
#   Finished row 138
# Row 139/152...
#   Finished row 139
# Row 140/152...
#   Finished row 140
# Row 141/152...
#   Finished row 141
# Row 142/152...
#   Finished row 142
# Row 143/152...
#   Finished row 143
# Row 144/152...
#   Finished row 144
# Row 145/152...
#   Finished row 145
# Row 146/152...
#   Finished row 146
# Row 147/152...
#   Finished row 147
# Row 148/152...
#   Finished row 148
# Row 149/152...
#   Finished row 149
# Row 150/152...
#   Finished row 150
# Row 151/152...
#   Finished row 151
# Row 152/152...
#   Finished row 152
# 		KERNEL
#
#
# [[0.00930418 0.00832993 0.14847695 ... 0.07010718 0.00295775 0.35296911]
#  [0.00832993 0.51095513 0.00066337 ... 0.0236652  0.09385874 0.00578599]
#  [0.14847695 0.00066337 0.35151857 ... 0.00304808 0.63886032 0.12476886]
#  ...
#  [0.02917971 0.02035273 0.26560076 ... 0.1546115  0.0823207  0.19315527]
#  [0.01320115 0.23113483 0.00589527 ... 0.00909525 0.06615865 0.36889292]
#  [0.00948778 0.00718973 0.52692361 ... 0.15605604 0.03722855 0.14325775]]

# %%
from sklearn.metrics import classification_report, confusion_matrix
print(confusion_matrix(y_test, predictions))
print(classification_report(y_test, predictions))
# Out:
# [[23 12]
#  [44 73]]
#               precision    recall  f1-score   support
#
#         -1.0       0.34      0.66      0.45        35
#          1.0       0.86      0.62      0.72       117
#
#     accuracy                           0.63       152
#    macro avg       0.60      0.64      0.59       152
# weighted avg       0.74      0.63      0.66       152

# %% [markdown]
# ## Other Experiments

# %% [markdown]
# # Angle encoding

# %%
import pennylane as qml
from pennylane import AngleEmbedding

n_qubits = 8

dev_kernel = qml.device("lightning.qubit", wires=n_qubits)

projector = np.zeros((2 ** n_qubits, 2 ** n_qubits))
projector[0, 0] = 1

@qml.qnode(dev_kernel)
def kernel(x1, x2):
    """The quantum kernel."""
    AngleEmbedding(x1, wires=range(n_qubits))
    qml.adjoint(AngleEmbedding)(x2, wires=range(n_qubits))
    return qml.expval(qml.Hermitian(projector, wires=range(n_qubits)))

def kernel_matrix(A, B):
    """Compute the matrix whose entries are the kernel
    evaluated on pairwise data from sets A and B."""
    K = np.zeros((len(A), len(B)))
    for i, a in enumerate(A):
        print(f"Row {i+1}/{len(A)}...")
        for j, b in enumerate(B):
            if j<i:
                K[i, j] = K[j, i]
                continue
            K[i, j] = kernel(a, b)
    return K

# %%
from sklearn.svm import SVC
svm = SVC(kernel=kernel_matrix, random_state=15)

# %%
svm.fit(X_train[:, :8], y_train)
# Out:
# Row 1/453...
# Row 2/453...
# Row 3/453...
# Row 4/453...
# Row 5/453...
# Row 6/453...
# Row 7/453...
# Row 8/453...
# Row 9/453...
# Row 10/453...
# Row 11/453...
# Row 12/453...
# Row 13/453...
# Row 14/453...
# Row 15/453...
# Row 16/453...
# Row 17/453...
# Row 18/453...
# Row 19/453...
# Row 20/453...
# Row 21/453...
# Row 22/453...
# Row 23/453...
# Row 24/453...
# Row 25/453...
# Row 26/453...
# Row 27/453...
# Row 28/453...
# Row 29/453...
# Row 30/453...
# Row 31/453...
# Row 32/453...
# Row 33/453...
# Row 34/453...
# Row 35/453...
# Row 36/453...
# Row 37/453...
# Row 38/453...
# Row 39/453...
# Row 40/453...
# Row 41/453...
# Row 42/453...
# Row 43/453...
# Row 44/453...
# Row 45/453...
# Row 46/453...
# Row 47/453...
# Row 48/453...
# Row 49/453...
# Row 50/453...
# Row 51/453...
# Row 52/453...
# Row 53/453...
# Row 54/453...
# Row 55/453...
# Row 56/453...
# Row 57/453...
# Row 58/453...
# Row 59/453...
# Row 60/453...
# Row 61/453...
# Row 62/453...
# Row 63/453...
# Row 64/453...
# Row 65/453...
# Row 66/453...
# Row 67/453...
# Row 68/453...
# Row 69/453...
# Row 70/453...
# Row 71/453...
# Row 72/453...
# Row 73/453...
# Row 74/453...
# Row 75/453...
# Row 76/453...
# Row 77/453...
# Row 78/453...
# Row 79/453...
# Row 80/453...
# Row 81/453...
# Row 82/453...
# Row 83/453...
# Row 84/453...
# Row 85/453...
# Row 86/453...
# Row 87/453...
# Row 88/453...
# Row 89/453...
# Row 90/453...
# Row 91/453...
# Row 92/453...
# Row 93/453...
# Row 94/453...
# Row 95/453...
# Row 96/453...
# Row 97/453...
# Row 98/453...
# Row 99/453...
# Row 100/453...
# Row 101/453...
# Row 102/453...
# Row 103/453...
# Row 104/453...
# Row 105/453...
# Row 106/453...
# Row 107/453...
# Row 108/453...
# Row 109/453...
# Row 110/453...
# Row 111/453...
# Row 112/453...
# Row 113/453...
# Row 114/453...
# Row 115/453...
# Row 116/453...
# Row 117/453...
# Row 118/453...
# Row 119/453...
# Row 120/453...
# Row 121/453...
# Row 122/453...
# Row 123/453...
# Row 124/453...
# Row 125/453...
# Row 126/453...
# Row 127/453...
# Row 128/453...
# Row 129/453...
# Row 130/453...
# Row 131/453...
# Row 132/453...
# Row 133/453...
# Row 134/453...
# Row 135/453...

# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.09      0.30      0.13        10
#          1.0       0.94      0.77      0.85       142
#
#     accuracy                           0.74       152
#    macro avg       0.51      0.54      0.49       152
# weighted avg       0.88      0.74      0.80       152

# %%
pca_scaled.explained_variance_ratio_.cumsum()[:50]
# Out:
# array([0.22903833, 0.34432509, 0.44397438, 0.48226919, 0.51015981,
#        0.5372165 , 0.56256489, 0.58392064, 0.60378196, 0.62320154,
#        0.64176394, 0.65776482, 0.67330645, 0.68808137, 0.7016061 ,
#        0.71392211, 0.72510308, 0.73549408, 0.74575494, 0.75552709,
#        0.76485879, 0.77356183, 0.78204747, 0.7898924 , 0.7972759 ,
#        0.80406404, 0.81071625, 0.81712266, 0.82289481, 0.82837587,
#        0.83356297, 0.83857102, 0.84320304, 0.8477888 , 0.85233169,
#        0.85662745, 0.86082281, 0.86495675, 0.86906397, 0.87298568,
#        0.8768181 , 0.88035072, 0.88384063, 0.88715539, 0.89041125,
#        0.89352168, 0.89661358, 0.89954863, 0.90244066, 0.90522866])

# %%
# classical benchmark

from sklearn.svm import SVC

model = SVC()

model.fit(X_train, y_train)

print(model.score(X_test, y_test))
# Out:
# 0.875

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()

model.fit(X_train[:,:5], y_train)

print(model.score(X_test[:,:5], y_test))
# Out:
# 0.8289473684210527
# /Users/Administrator/quantum/quant/lib/python3.11/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: divide by zero encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/Administrator/quantum/quant/lib/python3.11/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: overflow encountered in matmul
#   raw_prediction = X @ weights + intercept
# /Users/Administrator/quantum/quant/lib/python3.11/site-packages/sklearn/linear_model/_linear_loss.py:200: RuntimeWarning: invalid value encountered in matmul
#   raw_prediction = X @ weights + intercept

# %%
from sklearn.metrics import classification_report, confusion_matrix


y_pred = model.predict(X_test)
print(confusion_matrix(y_test, y_pred))
print(classification_report(y_test, y_pred))
# Out:
# [[ 17  18]
#  [  1 116]]
#               precision    recall  f1-score   support
#
#         -1.0       0.94      0.49      0.64        35
#          1.0       0.87      0.99      0.92       117
#
#     accuracy                           0.88       152
#    macro avg       0.91      0.74      0.78       152
# weighted avg       0.88      0.88      0.86       152

# %%
X_train
# Out:
# array([[ 1.00000000e+00, -9.00776449e+00, -1.46201812e+01, ...,
#          1.17057764e-01, -1.53903436e-01, -3.28671148e-01],
#        [ 1.00000000e+00, -3.44069601e+00, -2.08999290e+00, ...,
#          1.40390946e-02,  1.70018320e-01,  1.48733504e-01],
#        [ 1.00000000e+00, -1.35936202e+01, -1.57794468e+01, ...,
#          6.09411547e-02, -3.68417570e-01,  1.78274746e-01],
#        ...,
#        [ 1.00000000e+00,  2.07258596e+00, -6.86171315e+00, ...,
#         -9.80399371e-02, -8.17510739e-02,  2.21665445e-02],
#        [ 0.00000000e+00, -3.05898917e+00,  5.89082629e+00, ...,
#          1.61820350e-01,  3.53312687e-01,  1.53004761e-01],
#        [ 0.00000000e+00,  3.83496411e+00, -1.02977401e+00, ...,
#          6.85876540e-02, -8.47900587e-01, -1.66294452e-01]],
#       shape=(453, 151))

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y_scaled, test_size=0.2, random_state=15)
X_train, y_train = X_train.to_numpy(), y_train.to_numpy()
X_test, y_test = X_test.to_numpy(), y_test.to_numpy()

# %%
import optuna
from sklearn.svm import SVC
from sklearn.metrics import recall_score
def objective(trial):
    params = {
    'C': trial.suggest_float('C', 0.1, 100),
    'gamma': trial.suggest_categorical('gamma', ['scale', 'auto']),
    'kernel': trial.suggest_categorical('kernel', ['rbf', 'linear', 'poly']),
    "probability":False
    }
    model = SVC(**params, random_state=15)
    model.fit(X_train[:, :64], y_train)
    return recall_score(y_test, model.predict(X_test[:, :64]), pos_label=-1)
    # return model.score(X_test[:, :64], y_test)

study_baseline = optuna.create_study(direction="maximize")
study_baseline.optimize(objective, n_trials=100)
# Out:
# [I 2025-09-05 14:05:48,645] A new study created in memory with name: no-name-54f095fa-2ee3-4d25-a130-410237ec652c
# [I 2025-09-05 14:05:48,671] Trial 0 finished with value: 0.4 and parameters: {'C': 0.7143109207960794, 'gamma': 'scale', 'kernel': 'poly'}. Best is trial
 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 14:06:14,819] Trial 26 finished with value: 0.7714285714285715 and parameters: {'C': 43.24558672139587, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 14:06:14,833] Trial 27 finished with value: 0.7714285714285715 and parameters: {'C': 57.99629599572355, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 14:06:14,850] Trial 28 finished with value: 0.5714285714285714 and parameters: {'C': 35.648435017901704, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 6 with value: 0.7714285714285715.
# [W 2025-09-05 14:06:29,313] Trial 29 failed with parameters: {'C': 90.57996445238348, 'gamma': 'auto', 'kernel': 'linear'} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "/home/khaled/.local/lib/python3.10/site-packages/optuna/study/_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "/tmp/ipykernel_103906/3701079299.py", line 12, in objective
#     model.fit(X_train[:, :64], y_train)
#   File "/home/khaled/.local/lib/python3.10/site-packages/sklearn/base.py", line 1365, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "/home/khaled/.local/lib/python3.10/site-packages/sklearn/svm/_base.py", line 258, in fit
#     fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#   File "/home/khaled/.local/lib/python3.10/site-packages/sklearn/svm/_base.py", line 336, in _dense_fit
#     ) = libsvm.fit(
# KeyboardInterrupt
# [W 2025-09-05 14:06:29,319] Trial 29 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 17
#      14     # return model.score(X_test[:, :64], y_test)
#      16 study_baseline = optuna.create_study(direction="maximize")
# ---> 17 study_baseline.optimize(objective, n_trials=100)
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File ~/.local/lib/python3.10/site-packages/optuna/study/_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[9], line 12, in objective(trial)
#       5 params = {
#       6 'C': trial.suggest_float('C', 0.1, 100),
#       7 'gamma': trial.suggest_categorical('gamma', ['scale', 'auto']),
#       8 'kernel': trial.suggest_categorical('kernel', ['rbf', 'linear', 'poly']),
#       9 "probability":False
#      10 }
#      11 model = SVC(**params, random_state=15)
# ---> 12 model.fit(X_train[:, :64], y_train)
#      13 return recall_score(y_test, model.predict(X_test[:, :64]), pos_label=-1)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:258, in BaseLibSVM.fit(self, X, y, sample_weight)
#     255     print("[LibSVM]", end="")
#     257 seed = rnd.randint(np.iinfo("i").max)
# --> 258 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     259 # see comment on the other call to np.iinfo in this file
#     261 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:336, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     322 libsvm.set_verbosity_wrap(self.verbose)
#     324 # we don't pass **self.get_params() to allow subclasses to
#     325 # add other parameters to __init__
#     326 (
#     327     self.support_,
#     328     self.support_vectors_,
#     329     self._n_support,
#     330     self.dual_coef_,
#     331     self.intercept_,
#     332     self._probA,
#     333     self._probB,
#     334     self.fit_status_,
#     335     self._num_iter,
# --> 336 ) = libsvm.fit(
#     337     X,
#     338     y,
#     339     svm_type=solver_type,
#     340     sample_weight=sample_weight,
#     341     class_weight=getattr(self, "class_weight_", np.empty(0)),
#     342     kernel=kernel,
#     343     C=self.C,
#     344     nu=self.nu,
#     345     probability=self.probability,
#     346     degree=self.degree,
#     347     shrinking=self.shrinking,
#     348     tol=self.tol,
#     349     cache_size=self.cache_size,
#     350     coef0=self.coef0,
#     351     gamma=self._gamma,
#     352     epsilon=self.epsilon,
#     353     max_iter=self.max_iter,
#     354     random_seed=random_seed,
#     355 )
#     357 self._warn_from_fit_status()
#
# KeyboardInterrupt:

# %%
print(study_baseline.best_params)
# Out:
# {'C': 10.200101229666812, 'gamma': 'auto', 'kernel': 'poly'}

# %%
model = SVC(C=study_baseline.best_params['C'], gamma=study_baseline.best_params['gamma'], kernel=study_baseline.best_params['kernel'], probability=True, random_state=15)
model.fit(X_train[:, :64], y_train)
# Out:
# SVC(C=10.200101229666812, gamma='auto', kernel='poly', probability=True,
#     random_state=15)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, model.predict(X_test[:, :64])))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.85      0.80      0.82        35
#          1.0       0.94      0.96      0.95       117
#
#     accuracy                           0.92       152
#    macro avg       0.89      0.88      0.89       152
# weighted avg       0.92      0.92      0.92       152

# %%
X_train.shape, X_test.shape
# Out:
# ((604, 151), (152, 151))

# %%
np.savez()

# %%
def objective(trial):
    params = {
    'C': trial.suggest_float('C', 0.1, 100),
    'gamma': trial.suggest_categorical('gamma', ['scale', 'auto']),
    'kernel': trial.suggest_categorical('kernel', ['rbf', 'linear', 'poly']),
    "probability":False
    }
    model = SVC(**params, random_state=15)
    model.fit(X_train[:, :64], y_train)
    return recall_score(y_test, model.predict(X_test[:, :64]), pos_label=-1)
    # return model.score(X_test[:, :64], y_test)

study_baseline = optuna.create_study(direction="maximize")
study_baseline.optimize(objective, n_trials=100)
# Out:
# [I 2025-09-05 12:17:44,369] A new study created in memory with name: no-name-0f7ae522-0427-4fbf-a4a2-5eb4804bc170
# [I 2025-09-05 12:17:44,390] Trial 0 finished with value: 0.7428571428571429 and parameters: {'C': 57.73983287795363, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:44,403] Trial 1 finished with value: 0.7428571428571429 and parameters: {'C': 69.12397130309775, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:52,791] Trial 2 finished with value: 0.5428571428571428 and parameters: {'C': 37.385687162973475, 'gamma': 'auto', 'kernel': 'linear'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:52,803] Trial 3 finished with value: 0.6571428571428571 and parameters: {'C': 65.0740026537046, 'gamma': 'scale', 'kernel': 'poly'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:52,821] Trial 4 finished with value: 0.5714285714285714 and parameters: {'C': 21.899671278962067, 'gamma': 'auto', 'kernel': 'rbf'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:54,831] Trial 5 finished with value: 0.5428571428571428 and parameters: {'C': 15.35503252572167, 'gamma': 'scale', 'kernel': 'linear'}. Best is trial 0 with value: 0.7428571428571429.
# [I 2025-09-05 12:17:54,841] Trial 6 finished with value: 0.7714285714285715 and parameters: {'C': 30.512897469835814, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:17:54,854] Trial 7 finished with value: 0.7428571428571429 and parameters: {'C': 43.24873516652909, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:01,975] Trial 8 finished with value: 0.5428571428571428 and parameters: {'C': 76.54854354148914, 'gamma': 'auto', 'kernel': 'linear'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:01,986] Trial 9 finished with value: 0.7714285714285715 and parameters: {'C': 20.68014608777958, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:02,003] Trial 10 finished with value: 0.7428571428571429 and parameters: {'C': 99.29232824646928, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:02,015] Trial 11 finished with value: 0.7714285714285715 and parameters: {'C': 4.483235921240976, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:02,027] Trial 12 finished with value: 0.7714285714285715 and parameters: {'C': 31.41054023107614, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18:02,039] Trial 13 finished with value: 0.7714285714285715 and parameters: {'C': 5.639594563649137, 'gamma': 'auto', 'kernel': 'poly'}. Best is trial 6 with value: 0.7714285714285715.
# [I 2025-09-05 12:18
 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,691] Trial 84 finished with value: 0.8 and parameters: {'C': 21.33459665372112, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,703] Trial 85 finished with value: 0.7142857142857143 and parameters: {'C': 14.452080918681697, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,716] Trial 86 finished with value: 0.7428571428571429 and parameters: {'C': 90.20741523802535, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,730] Trial 87 finished with value: 0.7428571428571429 and parameters: {'C': 32.69538074839849, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,743] Trial 88 finished with value: 0.7714285714285715 and parameters: {'C': 29.142076210275032, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,756] Trial 89 finished with value: 0.8 and parameters: {'C': 19.19042967900461, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,771] Trial 90 finished with value: 0.7428571428571429 and parameters: {'C': 36.35606568527379, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,784] Trial 91 finished with value: 0.8 and parameters: {'C': 23.39969175748757, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,798] Trial 92 finished with value: 0.7714285714285715 and parameters: {'C': 27.28296227693365, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,811] Trial 93 finished with value: 0.8 and parameters: {'C': 22.587810710735507, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,824] Trial 94 finished with value: 0.7428571428571429 and parameters: {'C': 15.87281165644096, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,836] Trial 95 finished with value: 0.7714285714285715 and parameters: {'C': 26.25900803764784, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:30,850] Trial 96 finished with value: 0.6285714285714286 and parameters: {'C': 8.695955580764211, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:33,357] Trial 97 finished with value: 0.5428571428571428 and parameters: {'C': 19.917193788734046, 'gamma': 'scale', 'kernel': 'linear'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:33,373] Trial 98 finished with value: 0.7142857142857143 and parameters: {'C': 12.776383348411489, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.
# [I 2025-09-05 12:18:33,388] Trial 99 finished with value: 0.8 and parameters: {'C': 23.39488746550633, 'gamma': 'scale', 'kernel': 'rbf'}. Best is trial 57 with value: 0.8.

# %%
model = SVC(kernel=qkernel, random_state=15)

# %%
model.fit(X_train[:, :64], y_train)
# Out:
# Row 1/604...
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[67], line 1
# ----> 1 model.fit(X_train[:, :64], y_train)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/base.py:1365, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1358     estimator._validate_params()
#    1360 with config_context(
#    1361     skip_parameter_validation=(
#    1362         prefer_skip_nested_validation or global_skip_validation
#    1363     )
#    1364 ):
# -> 1365     return fit_method(estimator, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:258, in BaseLibSVM.fit(self, X, y, sample_weight)
#     255     print("[LibSVM]", end="")
#     257 seed = rnd.randint(np.iinfo("i").max)
# --> 258 fit(X, y, sample_weight, solver_type, kernel, random_seed=seed)
#     259 # see comment on the other call to np.iinfo in this file
#     261 self.shape_fit_ = X.shape if hasattr(X, "shape") else (n_samples,)
#
# File ~/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:317, in BaseLibSVM._dense_fit(self, X, y, sample_weight, solver_type, kernel, random_seed)
#     313 if callable(self.kernel):
#     314     # you must store a reference to X to compute the kernel in predict
#     315     # TODO: add keyword copy to copy on demand
#     316     self.__Xfit = X
# --> 317     X = self._compute_kernel(X)
#     319     if X.shape[0] != X.shape[1]:
#     320         raise ValueError("X.shape[0] should be equal to X.shape[1]")
#
# File ~/.local/lib/python3.10/site-packages/sklearn/svm/_base.py:515, in BaseLibSVM._compute_kernel(self, X)
#     511 """Return the data transformed by a callable kernel"""
#     512 if callable(self.kernel):
#     513     # in the case of precomputed kernel given as a function, we
#     514     # have to compute explicitly the kernel matrix
# --> 515     kernel = self.kernel(X, self.__Xfit)
#     516     if sp.issparse(kernel):
#     517         kernel = kernel.toarray()
#
# Cell In[24], line 25, in qkernel(A, B)
#      23             K[i, j] = K[j, i]
#      24             continue
# ---> 25         K[i, j] = kernel_circ(a, b)[0]
#      26     print(f"  Finished row {i+1}")
#      27 print("\t\tKERNEL\t\t\n\n")
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:922, in QNode.__call__(self, *args, **kwargs)
#     919     from ._capture_qnode import capture_qnode  # pylint: disable=import-outside-toplevel
#     921     return capture_qnode(self, *args, **kwargs)
# --> 922 return self._impl_call(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:890, in QNode._impl_call(self, *args, **kwargs)
#     887 def _impl_call(self, *args, **kwargs) -> Result:
#     888
#     889     # construct the tape
# --> 890     tape = self.construct(args, kwargs)
#     892     # Calculate the classical jacobians if necessary
#     893     self._transform_program.set_classical_component(self, args, kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/logging/decorators.py:61, in log_string_debug_func.<locals>.wrapper_entry(*args, **kwargs)
#      54     s_caller = "::L".join(
#      55         [str(i) for i in inspect.getouterframes(inspect.currentframe(), 2)[1][1:3]]
#      56     )
#      57     lgr.debug(
#      58         f"Calling {f_string} from {s_caller}",
#      59         **_debug_log_kwargs,
#      60     )
# ---> 61 return func(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/workflow/qnode.py:876, in QNode.construct(self, args, kwargs)
#     874 with pldb_device_manager(self.device):
#     875     with AnnotatedQueue() as q:
# --> 876         self._qfunc_output = self.func(*args, **kwargs)
#     878 tape = QuantumScript.from_queue(q, shots)
#     880 params = tape.get_parameters(trainable_only=False)
#
# Cell In[24], line 11, in kernel_circ(a, b)
#       9 @qml.qnode(dev)
#      10 def kernel_circ(a, b):
# ---> 11     qml.AngleEmbedding(a, wires=range(n_qubits))
#      12     qml.adjoint(qml.AngleEmbedding)(b, wires=range(n_qubits))
#      13     return qml.expval(qml.Hermitian(projector, wires=range(n_qubits)))
#
# File ~/.local/lib/python3.10/site-packages/pennylane/capture/capture_meta.py:30, in _stop_autograph.<locals>.new_f(*args, **kwargs)
#      29 def new_f(*args, **kwargs):
# ---> 30     return f(*args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/capture/capture_meta.py:97, in CaptureMeta.__call__(cls, *args, **kwargs)
#      93 if enabled():
#      94     # when tracing is enabled, we want to
#      95     # use bind to construct the class if we want class construction to add it to the jaxpr
#      96     return cls._primitive_bind_call(*args, **kwargs)
# ---> 97 return type.__call__(cls, *args, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/pennylane/templates/embeddings/angle.py:92, in AngleEmbedding.__init__(self, features, wires, rotation, id)
#      90 n_features = shape[0]
#      91 if n_features > len(wires):
# ---> 92     raise ValueError(
#      93         f"Features must be of length {len(wires)} or less; got length {n_features}."
#      94     )
#      96 self._rotation = rotation
#      97 self._hyperparameters = {"rotation": ROT[rotation]}
#
# ValueError: Features must be of length 8 or less; got length 64.

# %%
predicted = model.predict(X_test[:, :64])
# Out:
# Row 1/152...
#   Finished row 1
# Row 2/152...
#   Finished row 2
# Row 3/152...
#   Finished row 3
# Row 4/152...
#   Finished row 4
# Row 5/152...
#   Finished row 5
# Row 6/152...
#   Finished row 6
# Row 7/152...
#   Finished row 7
# Row 8/152...
#   Finished row 8
# Row 9/152...
#   Finished row 9
# Row 10/152...
#   Finished row 10
# Row 11/152...
#   Finished row 11
# Row 12/152...
#   Finished row 12
# Row 13/152...
#   Finished row 13
# Row 14/152...
#   Finished row 14
# Row 15/152...
#   Finished row 15
# Row 16/152...
#   Finished row 16
# Row 17/152...
#   Finished row 17
# Row 18/152...
#   Finished row 18
# Row 19/152...
#   Finished row 19
# Row 20/152...
#   Finished row 20
# Row 21/152...
#   Finished row 21
# Row 22/152...
#   Finished row 22
# Row 23/152...
#   Finished row 23
# Row 24/152...
#   Finished row 24
# Row 25/152...
#   Finished row 25
# Row 26/152...
#   Finished row 26
# Row 27/152...
#   Finished row 27
# Row 28/152...
#   Finished row 28
# Row 29/152...
#   Finished row 29
# Row 30/152...
#   Finished row 30
# Row 31/152...
#   Finished row 31
# Row 32/152...
#   Finished row 32
# Row 33/152...
#   Finished row 33
# Row 34/152...
#   Finished row 34
# Row 35/152...
#   Finished row 35
# Row 36/152...
#   Finished row 36
# Row 37/152...
#   Finished row 37
# Row 38/152...
#   Finished row 38
# Row 39/152...
#   Finished row 39
# Row 40/152...
#   Finished row 40
# Row 41/152...
#   Finished row 41
# Row 42/152...
#   Finished row 42
# Row 43/152...
#   Finished row 43
# Row 44/152...
#   Finished row 44
# Row 45/152...
#   Finished row 45
# Row 46/152...
#   Finished row 46
# Row 47/152...
#   Finished row 47
# Row 48/152...
#   Finished row 48
# Row 49/152...
#   Finished row 49
# Row 50/152...
#   Finished row 50
# Row 51/152...
#   Finished row 51
# Row 52/152...
#   Finished row 52
# Row 53/152...
#   Finished row 53
# Row 54/152...
#   Finished row 54
# Row 55/152...
#   Finished row 55
# Row 56/152...
#   Finished row 56
# Row 57/152...
#   Finished row 57
# Row 58/152...
#   Finished row 58
# Row 59/152...
#   Finished row 59
# Row 60/152...
#   Finished row 60
# Row 61/152...
#   Finished row 61
# Row 62/152...
#   Finished row 62
# Row 63/152...
#   Finished row 63
# Row 64/152...
#   Finished row 64
# Row 65/152...
#   Finished row 65
# Row 66/152...
#   Finished row 66
# Row 67/152...
#   Finished row 67
# Row 68/152...
#   Finished row 68
# Row 69/152...
#   Finished row 69
# Row 70/152...
#   Finished row 70
# Row 71/152...
#   Finished row 71
# Row 72/152...
#   Finished row 72
# Row 73/152...
#   Finished row 73
# Row 74/152...
#   Finished row 74
# Row 75/152...
#   Finished row 75
# Row 76/152...
#   Finished row 76
# Row 77/152...
#   Finished row 77
# Row 78/152...
#   Finished row 78
# Row 79/152...
#   Finished row 79
# Row 80/152...
#   Finished row 80
# Row 81/152...
#   Finished row 81
# Row 82/152...
#   Finished row 82
# Row 83/152...
#   Finished row 83
# Row 84/152...
#   Finished row 84
# Row 85/152...
#   Finished row 85
# Row 86/152...
#   Finished row 86
# Row 87/152...
#   Finished row 87
# Row 88/152...
#   Finished row 88
# Row 89/152...
#   Finished row 89
# Row 90/152...
#   Finished row 90
# Row 91/152...
#   Finished row 91
# Row 92/152...
#   Finished row 92
# Row 93/152...
#   Finished row 93
# Row 94/152...
#   Finished row 94
# Row 95/152...
#   Finished row 95
# Row 96/152...
#   Finished row 96
# Row 97/152...
#   Finished row 97
# Row 98/152...
#   Finished row 98
# Row 99/152...
#   Finished row 99
# Row 100/152...
#   Finished row 100
# Row 101/152...
#   Finished row 101
# Row 102/152...
#   Finished row 102
# Row 103/152...
#   Finished row 103
# Row 104/152...
#   Finished row 104
# Row 105/152...
#   Finished row 105
# Row 106/152...
#   Finished row 106
# Row 107/152...
#   Finished row 107
# Row 108/152...
#   Finished row 108
# Row 109/152...
#   Finished row 109
# Row 110/152...
#   Finished row 110
# Row 111/152...
#   Finished row 111
# Row 112/152...
#   Finished row 112
# Row 113/152...
#   Finished row 113
# Row 114/152...
#   Finished row 114
# Row 115/152...
#   Finished row 115
# Row 116/152...
#   Finished row 116
# Row 117/152...
#   Finished row 117
# Row 118/152...
#   Finished row 118
# Row 119/152...
#   Finished row 119
# Row 120/152...
#   Finished row 120
# Row 121/152...
#   Finished row 121
# Row 122/152...
#   Finished row 122
# Row 123/152...
#   Finished row 123
# Row 124/152...
#   Finished row 124
# Row 125/152...
#   Finished row 125
# Row 126/152...
#   Finished row 126
# Row 127/152...
#   Finished row 127
# Row 128/152...
#   Finished row 128
# Row 129/152...
#   Finished row 129
# Row 130/152...
#   Finished row 130
# Row 131/152...
#   Finished row 131
# Row 132/152...
#   Finished row 132
# Row 133/152...
#   Finished row 133
# Row 134/152...
#   Finished row 134
# Row 135/152...
#   Finished row 135
# Row 136/152...
#   Finished row 136
# Row 137/152...
#   Finished row 137
# Row 138/152...
#   Finished row 138
# Row 139/152...
#   Finished row 139
# Row 140/152...
#   Finished row 140
# Row 141/152...
#   Finished row 141
# Row 142/152...
#   Finished row 142
# Row 143/152...
#   Finished row 143
# Row 144/152...
#   Finished row 144
# Row 145/152...
#   Finished row 145
# Row 146/152...
#   Finished row 146
# Row 147/152...
#   Finished row 147
# Row 148/152...
#   Finished row 148
# Row 149/152...
#   Finished row 149
# Row 150/152...
#   Finished row 150
# Row 151/152...
#   Finished row 151
# Row 152/152...
#   Finished row 152
# 		KERNEL
#
#
# [[0.00930418 0.00832993 0.14847695 ... 0.07010718 0.00295775 0.35296911]
#  [0.00832993 0.51095513 0.00066337 ... 0.0236652  0.09385874 0.00578599]
#  [0.14847695 0.00066337 0.35151857 ... 0.00304808 0.63886032 0.12476886]
#  ...
#  [0.02917971 0.02035273 0.26560076 ... 0.1546115  0.0823207  0.19315527]
#  [0.01320115 0.23113483 0.00589527 ... 0.00909525 0.06615865 0.36889292]
#  [0.00948778 0.00718973 0.52692361 ... 0.15605604 0.03722855 0.14325775]]

# %%
print(classification_report(y_test, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         -1.0       0.34      0.66      0.45        35
#          1.0       0.86      0.62      0.72       117
#
#     accuracy                           0.63       152
#    macro avg       0.60      0.64      0.59       152
# weighted avg       0.74      0.63      0.66       152

# %%
svq_pipe = Pipeline([
    ('scaler', StandardScaler()),
    ('svm', SVC(kernel=qkernel, class_weight='balanced'))
])

# %%
svq_pipe.fit(X_train_subset, y_train_subset)
# Out:
# Row 1/604...
#   Finished row 1
# Row 2/604...
#   Finished row 2
# Row 3/604...
#   Finished row 3
# Row 4/604...
#   Finished row 4
# Row 5/604...
#   Finished row 5
# Row 6/604...
#   Finished row 6
# Row 7/604...
#   Finished row 7
# Row 8/604...
#   Finished row 8
# Row 9/604...
#   Finished row 9
# Row 10/604...
#   Finished row 10
# Row 11/604...
#   Finished row 11
# Row 12/604...
#   Finished row 12
# Row 13/604...
#   Finished row 13
# Row 14/604...
#   Finished row 14
# Row 15/604...
#   Finished row 15
# Row 16/604...
#   Finished row 16
# Row 17/604...
#   Finished row 17
# Row 18/604...
#   Finished row 18
# Row 19/604...
#   Finished row 19
# Row 20/604...
#   Finished row 20
# Row 21/604...
#   Finished row 21
# Row 22/604...
#   Finished row 22
# Row 23/604...
#   Finished row 23
# Row 24/604...
#   Finished row 24
# Row 25/604...
#   Finished row 25
# Row 26/604...
#   Finished row 26
# Row 27/604...
#   Finished row 27
# Row 28/604...
#   Finished row 28
# Row 29/604...
#   Finished row 29
# Row 30/604...
#   Finished row 30
# Row 31/604...
#   Finished row 31
# Row 32/604...
#   Finished row 32
# Row 33/604...
#   Finished row 33
# Row 34/604...
#   Finished row 34
# Row 35/604...
#   Finished row 35
# Row 36/604...
#   Finished row 36
# Row 37/604...
#   Finished row 37
# Row 38/604...
#   Finished row 38
# Row 39/604...
#   Finished row 39
# Row 40/604...
#   Finished row 40
# Row 41/604...
#   Finished row 41
# Row 42/604...
#   Finished row 42
# Row 43/604...
#   Finished row 43
# Row 44/604...
#   Finished row 44
# Row 45/604...
#   Finished row 45
# Row 46/604...
#   Finished row 46
# Row 47/604...
#   Finished row 47
# Row 48/604...
#   Finished row 48
# Row 49/604...
#   Finished row 49
# Row 50/604...
#   Finished row 50
# Row 51/604...
#   Finished row 51
# Row 52/604...
#   Finished row 52
# Row 53/604...
#   Finished row 53
# Row 54/604...
#   Finished row 54
# Row 55/604...
#   Finished row 55
# Row 56/604...
#   Finished row 56
# Row 57/604...
#   Finished row 57
# Row 58/604...
#   Finished row 58
# Row 59/604...
#   Finished row 59
# Row 60/604...
#   Finished row 60
# Row 61/604...
#   Finished row 61
# Row 62/604...
#   Finished row 62
# Row 63/604...
#   Finished row 63
# Row 64/604...
#   Finished row 64
# Row 65/604...
#   Finished row 65
# Row 66/604...
#   Finished row 66
# Row 67/604...
#   Finished row 67
# Row 68/604...
#   Finished row 68
# Row 69/604...
#   Finished row 69
# Row 70/604...
#   Finished row 70
# Row 71/604...
#   Finished row 71
# Row 72/604...
#   Finished row 72
# Row 73/604...
#   Finished row 73
# Row 74/604...
#   Finished row 74
# Row 75/604...
#   Finished row 75
# Row 76/604...
#   Finished row 76
# Row 77/604...
#   Finished row 77
# Row 78/604...
#   Finished row 78
# Row 79/604...
#   Finished row 79
# Row 80/604...
#   Finished row 80
# Row 81/604...
#   Finished row 81
# Row 82/604...
#   Finished row 82
# Row 83/604...
#   Finished row 83
# Row 84/604...
#   Finished row 84
# Row 85/604...
#   Finished row 85
# Row 86/604...
#   Finished row 86
# Row 87/604...
#   Finished row 87
# Row 88/604...
#   Finished row 88
# Row 89/604...
#   Finished row 89
# Row 90/604...
#   Finished row 90
# Row 91/604...
#   Finished row 91
# Row 92/604...
#   Finished row 92
# Row 93/604...
#   Finished row 93
# Row 94/604...
#   Finished row 94
# Row 95/604...
#   Finished row 95
# Row 96/604...
#   Finished row 96
# Row 97/604...
#   Finished row 97
# Row 98/604...
#   Finished row 98
# Row 99/604...
#   Finished row 99
# Row 100/604...
#   Finished row 100
# Row 101/604...
#   Finished row 101
# Row 102/604...
#   Finished row 102
# Row 103/604...
#   Finished row 103
# Row 104/604...
#   Finished row 104
# Row 105/604...
#   Finished row 105
# Row 106/604...
#   Finished row 106
# Row 107/604...
#   Finished row 107
# Row 108/604...
